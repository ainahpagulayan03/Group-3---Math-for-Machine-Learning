# %%
import pandas
df = pandas.read_csv('social_media_interactions_contaminated.csv')
df
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3195  8d8fe8bd-2009-4a15-be37-83dba3cef447
# 3196  1756838b-8368-4852-b4a5-32a23643a3dd
# 3197  eb8bb3ce-e182-4a9c-8084-c55c738815e1
# 3198  a5d08a95-9dba-4e3d-b997-1cfdde6a89ef
# 3199  f8146100-569d-4cda-9d64-88c6ad98de5f
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11        NaN
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11        NaN
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %%
df = df.drop(columns = "InteractionID")
df
# Out:
#                                 CustomerID InteractionDate   Platform  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261      2023-07-11        NaN
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa      2023-07-06    Twitter
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2      2024-05-24  Instagram
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285      2023-11-01  Instagram
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18      2023-07-08  Instagram
# ...                                    ...             ...        ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8      2024-04-30    Twitter
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc      2024-05-16        NaN
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122      2023-12-16    Twitter
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b      2024-01-28   Facebook
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8      2024-06-29    Twitter
#
#      InteractionType      Sentiment
# 0            Comment            NaN
# 1              Share            NaN
# ...

# %%
df = df.fillna('')
df
# Out:
#                                 CustomerID InteractionDate   Platform  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261      2023-07-11
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa      2023-07-06    Twitter
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2      2024-05-24  Instagram
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285      2023-11-01  Instagram
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18      2023-07-08  Instagram
# ...                                    ...             ...        ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8      2024-04-30    Twitter
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc      2024-05-16
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122      2023-12-16    Twitter
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b      2024-01-28   Facebook
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8      2024-06-29    Twitter
#
#      InteractionType      Sentiment
# 0            Comment
# 1              Share
# 2            Comment        Neutral
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3020 entries, 0 to 3194
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       3020 non-null   object
#  1   InteractionDate  3020 non-null   object
#  2   Platform         3020 non-null   object
#  3   InteractionType  3020 non-null   object
#  4   Sentiment        3020 non-null   object
# dtypes: object(5)
# memory usage: 141.6+ KB

# %%
df.describe()
# Out:
#                                   CustomerID InteractionDate   Platform  \
# count                                   3020            3020       3020
# unique                                  1893             450          4
# top     a14c5d2f-87d8-4caf-b91e-ab6865872c37      2023-07-02  Instagram
# freq                                       5              16        921
#
#        InteractionType Sentiment
# count             3020      3020
# unique               3         6
# top            Comment  Positive
# freq              1018       905

# %%
df.isnull().sum()
# Out:
# CustomerID         0
# InteractionDate    0
# Platform           0
# InteractionType    0
# Sentiment          0
# dtype: int64

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.corr()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# ...
